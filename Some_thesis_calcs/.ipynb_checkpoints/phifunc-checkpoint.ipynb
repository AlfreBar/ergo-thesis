# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xvec=np.linspace(-12,12)
def f(x):
    return 1/(np.exp(-x)+1)
plt.plot(xvec,f(xvec))
plt.xticks([-9,9],[0,r"$\tau$"])
plt.yticks([0,1],[0,r"$\tau$"])
plt.show()
