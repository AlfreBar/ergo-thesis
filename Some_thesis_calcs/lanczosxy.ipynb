# %%
import numpy as np
import matplotlib.pyplot as plt
from timeit import default_timer as timer
import qutip as q
from scipy.sparse.linalg import LinearOperator
from scipy.sparse.linalg import eigsh
from scipy import integrate,special
from scipy.linalg import eig,eigh,eigvals,eigvalsh
import pickle 
from math import floor, ceil
from functions import diagonalize_2,diagonalize,xymodel

# %%
for length in [6,10,14]:
    lambdarange=np.linspace(0.8,1.2)

    measures={}

    for i,l in enumerate(lambdarange):

        Energies,psis=diagonalize(2,length,xymodel(l,0.6,0.000),False)

        measures[i]=Energies[1]-Energies[0]

    plt.plot(lambdarange,[measures[i] for i in measures],label=length)
    plt.legend()
