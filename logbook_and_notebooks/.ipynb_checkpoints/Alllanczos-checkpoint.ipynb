# %%
import numpy as np
import matplotlib.pyplot as plt
from timeit import default_timer as timer
from dmrgwaytorho import *
import qutip as q
from scipy import integrate,special
from scipy.linalg import eig,eigh,eigvals,eigvalsh
from scipy.sparse.linalg import eigs
import pickle 
from functions import doApplyHam,isingmodel,diagonalize
from functions import isingmodel_rev,isingmodel_rev_frac2

# %%
length=16
lambdarange=np.linspace(0.1,2)

# %%
dictionary_open0={}
dictionary_open1={}

for l in lambdarange:
    
    Energies,psis=diagonalize(2,length,isingmodel_rev_frac2(l,0.0001),False)
    
    reshapedpsi0=psis[:,0].reshape(2**int((length-2)/2),4,2**int((length-2)/2)).transpose(1,0,2).reshape(4,-1)
    
    rhomagn0 = np.dot(reshapedpsi0, reshapedpsi0.conjugate().transpose())
    
    reshapedpsi1=psis[:,1].reshape(2**int((length-2)/2),4,2**int((length-2)/2)).transpose(1,0,2).reshape(4,-1)
    
    rhomagn1 = np.dot(reshapedpsi1, reshapedpsi1.conjugate().transpose())
    
    dictionary_open0[l]=rhomagn0
    
    dictionary_open1[l]=rhomagn1

# %%
rho_effective={}
for el in lambdarange:
    #rho_effective[el]=1/2*dictionary_open0[el]+1/2*dictionary_open1[el]
    rho_effective[el]=dictionary_open0[el]
fig, axs = plt.subplots(2, 2,sharex=True,figsize=[12,12])

ind=[(x,y) for x in range(2) for y in range(2)]

for k in range(4):
    kb=format(k,"02b")
    kbvec=[int(x) for x in str(kb)]
    specvec= np.zeros_like(lambdarange)
    
    for i,el in enumerate(lambdarange):
        specvec[i]=np.sort(eigvalsh(rho_effective[el]))[k]
    
    axs[ind[k]].plot(lambdarange,specvec,label="exp")
    axs[kbvec[0], kbvec[1]].set_title('d'+str(k))
handles, labels = axs[1,1].get_legend_handles_labels()
fig.legend(handles, labels, loc='center')
fig.suptitle(r"open chain h=0.0001 rho0",fontsize=15)
axs[1,1].set_xlabel(r"$\lambda$")
axs[1,0].set_xlabel(r"$\lambda$")
plt.show()    
rho_effective={}
for el in lambdarange:
    rho_effective[el]=1/2*dictionary_open0[el]+1/2*dictionary_open1[el]
    #rho_effective[el]=dictionary_open0[el]
fig, axs = plt.subplots(2, 2,sharex=True,figsize=[12,12])

ind=[(x,y) for x in range(2) for y in range(2)]

for k in range(4):

    specvec= np.zeros_like(lambdarange)
    
    for i,el in enumerate(lambdarange):
        specvec[i]=np.sort(eigvalsh(rho_effective[el]))[k]
    
    axs[ind[k]].plot(lambdarange,specvec,label="exp")
    axs[ind[k]].set_title('d'+str(k))
handles, labels = axs[1,1].get_legend_handles_labels()
fig.legend(handles, labels, loc='center')
fig.suptitle(r"open chain h=0.0001 rho0++rho1",fontsize=15)
axs[1,1].set_xlabel(r"$\lambda$")
axs[1,0].set_xlabel(r"$\lambda$")
plt.show()

# %%
dictionary_open0={}
dictionary_open1={}

for l in lambdarange:
    
    Energies,psis=diagonalize(2,length,isingmodel_rev_frac2(l,0.00),False)
    
    reshapedpsi0=psis[:,0].reshape(2**int((length-2)/2),4,2**int((length-2)/2)).transpose(1,0,2).reshape(4,-1)
    
    rhomagn0 = np.dot(reshapedpsi0, reshapedpsi0.conjugate().transpose())
    
    reshapedpsi1=psis[:,1].reshape(2**int((length-2)/2),4,2**int((length-2)/2)).transpose(1,0,2).reshape(4,-1)
    
    rhomagn1 = np.dot(reshapedpsi1, reshapedpsi1.conjugate().transpose())
    
    dictionary_open0[l]=rhomagn0
    
    dictionary_open1[l]=rhomagn1

# %%
rho_effective={}
for el in lambdarange:
    rho_effective[el]=dictionary_open0[el]
    
fig, axs = plt.subplots(2, 2,sharex=True,figsize=[12,12])

ind=[(x,y) for x in range(2) for y in range(2)]

for k in range(4):

    specvec= np.zeros_like(lambdarange)
    
    for i,el in enumerate(lambdarange):
        specvec[i]=np.sort(eigvalsh(rho_effective[el]))[k]
    
    axs[ind[k]].plot(lambdarange,specvec,label="exp")
    axs[ind[k]].set_title('d'+str(k))
handles, labels = axs[1,1].get_legend_handles_labels()
fig.legend(handles, labels, loc='center')
fig.suptitle(r"open h=0",fontsize=15)
axs[1,1].set_xlabel(r"$\lambda$")
axs[1,0].set_xlabel(r"$\lambda$")
plt.show()

# %%
dictionary_open0={}
dictionary_open1={}

for l in lambdarange:
    
    Energies,psis=diagonalize(2,length,isingmodel_rev_frac2(l,0.00),True)
    
    reshapedpsi0=psis[:,0].reshape(2**int((length-2)/2),4,2**int((length-2)/2)).transpose(1,0,2).reshape(4,-1)
    
    rhomagn0 = np.dot(reshapedpsi0, reshapedpsi0.conjugate().transpose())
    
    reshapedpsi1=psis[:,1].reshape(2**int((length-2)/2),4,2**int((length-2)/2)).transpose(1,0,2).reshape(4,-1)
    
    rhomagn1 = np.dot(reshapedpsi1, reshapedpsi1.conjugate().transpose())
    
    dictionary_open0[l]=rhomagn0,Energies,psis
    
    dictionary_open1[l]=rhomagn1

# %%
rho_effective={}
for el in lambdarange:
    rho_effective[el]=dictionary_open0[el][0]
    
fig, axs = plt.subplots(2, 2,sharex=True,figsize=[12,12])

ind=[(x,y) for x in range(2) for y in range(2)]

for k in range(4):

    specvec= np.zeros_like(lambdarange)
    
    for i,el in enumerate(lambdarange):
        specvec[i]=np.sort(eigvalsh(rho_effective[el]))[k]
    
    axs[ind[k]].plot(lambdarange,specvec,label="exp")
    axs[ind[k]].set_title('d'+str(k))
handles, labels = axs[1,1].get_legend_handles_labels()
fig.legend(handles, labels, loc='center')
fig.suptitle(r"periodic h=0",fontsize=15)
axs[1,1].set_xlabel(r"$\lambda$")
axs[1,0].set_xlabel(r"$\lambda$")
plt.show()

# %%
for l in lambdarange:
    print(dictionary_open0[l][2])
# Out:
# [[ 0.00701133 -0.00433646]
#  [ 0.00411392  0.00665153]
#  [ 0.00411392  0.00665153]
#  ...
#  [ 0.00204223  0.00330195]
#  [ 0.00204223  0.00330195]
#  [ 0.00314829 -0.00194719]]
# [[ 0.00703635  0.00657847]
#  [-0.00610496  0.00652988]
#  [-0.00610496  0.00652988]
#  ...
#  [-0.00230892  0.00246963]
#  [-0.00230892  0.00246963]
#  [ 0.00231426  0.00216367]]
#  [-6.65076223e-16  2.05534937e-01]
#  ...
#  [ 1.98193743e-17  3.04270238e-06]
#  [-2.04248252e-17  3.04270238e-06]
#  [ 5.58359477e-07  3.84850310e-16]]
# [[-8.30141735e-01  1.20965009e-15]
#  [-1.46062432e-16 -2.07546342e-01]
#  [ 5.99036191e-17 -2.07546342e-01]
#  ...
#  [-2.24547533e-17 -2.60120304e-06]
#  [ 1.14533433e-17 -2.60120304e-06]
#  [-4.61174195e-07 -2.77255447e-17]]
# [[ 8.37660093e-01 -2.06753786e-15]
#  [ 3.10091484e-15  2.09422775e-01]
#  [ 2.77370803e-15  2.09422775e-01]
#  ...
#  [-1.00276655e-16  2.23101923e-06]
#  [-5.08381525e-17  2.23101923e-06]
#  [ 3.82722309e-07  1.80801311e-16]]
# [[-8.44682571e-01 -2.62250144e-15]
#  [-2.19874697e-15  2.11176188e-01]
#  [-2.10211277e-15  2.11176188e-01]
#  ...
#  [-4.36935017e-17  1.91954522e-06]
#  [-7.39824837e-17  1.91954522e-06]
#  [-3.19052441e-07 -7.67854978e-17]]
# [[-8.51252945e-01 -5.93974920e-15]
#  [-5.17250675e-16  2.12817229e-01]
#  [-6.91350785e-16  2.12817229e-01]
#  ...
#  [ 1.25605409e-16  1.65657846e-06]
#  [-1.16368612e-16  1.65657846e-06]
#  [-2.67116416e-07  2.27636650e-16]]
# [[ 8.57410063e-01  1.12096205e-15]
#  [ 1.77839120e-15 -2.14355408e-01]
#  [ 9.42638216e-16 -2.14355408e-01]
#  ...
#  [-5.21574100e-17 -1.43383192e-06]
#  [ 7.01901216e-17 -1.43383192e-06]
#  [ 2.24547321e-07  4.09488698e-17]]
# [[ 8.63188535e-01 -2.41999029e-16]
#  [-1.20395253e-15 -2.15799242e-01]
#  [-1.59249676e-15 -2.15799242e-01]
#  ...
#  [ 1.02125306e-16 -1.24455030e-06]
#  [ 5.56060505e-17 -1.24455030e-06]
#  [ 1.89495796e-07  2.57134454e-17]]
# [[ 8.68619310e-01  2.51325488e-16]
#  [-3.12545453e-16  2.17156373e-01]
#  [-8.53122875e-16  2.17156373e-01]
#  ...
#  [-9.55495405e-18  1.08320745e-06]
#  [-3.28898593e-18  1.08320745e-06]
#  [ 1.60508336e-07 -4.83668930e-17]]
# [[ 8.73730151e-01 -4.12599755e-15]
#  [ 1.73964129e-15  2.18433677e-01]
#  [ 1.00395962e-15  2.18433677e-01]
#  ...
#  [-2.61285707e-17  9.45266884e-07]
#  [ 6.19044154e-18  9.45266884e-07]
#  [ 1.36436152e-07 -1.47696236e-16]]

# %%
x=np.linspace(-2,2)
a=-2
b=1

plt.hlines(0,-2,2)
plt.plot(x,a*x**2+b*x**4)
plt.axis.set_visible(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-b3b68f086f41> in <module>
#       5 plt.hlines(0,-2,2)
#       6 plt.plot(x,a*x**2+b*x**4)
# ----> 7 plt.axis.set_visible(True)
#
# AttributeError: 'function' object has no attribute 'set_visible'
